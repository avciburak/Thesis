# %%
from matplotlib import pyplot as plt

# %%
iou=[]
with open("C:/Users/vatan/Downloads/groundtruth_query_2.txt") as f:
    for line in f:
        if line[0]=="f":
            splitted_line=line.split(" | ")
            iou_str=splitted_line[3]
            #if float(iou_str)>0.3:
            iou.append(float(iou_str))

# %%
print(iou[0:10])
# Out:
# [0.9767441860465116, 0.0, 0.0, 0.0, 0.4407764733232593, 0.004465592972181552, 0.0, 0.4164703665316122, 0.0, 0.05555942351876349]

# %%
x=list(range(len(iou)))
y=iou
plt.plot(x,y)
plt.xlabel("Frame Number")
plt.ylabel("IoU Score")
plt.title("Query Image Updated Every Five Comparison")
plt.show()

# %%
acc=[]
with open("C:/Users/vatan/Downloads/groundtruth_query_2.txt") as f:
    for line in f:
        if line[0]=="f":
            splitted_line=line.split(" | ")
            acc_str=splitted_line[4]
            acc.append(float(acc_str))

# %%
x=list(range(len(acc)))
y=acc
plt.plot(x,y)
plt.xlabel("Frame Number")
plt.ylabel("Accuracy")
plt.title("Query Image Updated Every Five Comparison")
plt.show()

# %%
tpr=[]
with open("C:/Users/vatan/Downloads/groundtruth_query_2.txt") as f:
    for line in f:
        if line[0]=="f":
            splitted_line=line.split(" | ")
            tpr_str=splitted_line[5]
            tpr.append(float(tpr_str))

# %%
x=list(range(len(tpr)))
y=tpr
plt.plot(x,y)
plt.xlabel("Frame Number")
plt.ylabel("True Positive Rate")
plt.title("Query Image Updated Every Five Comparison")
plt.show()
