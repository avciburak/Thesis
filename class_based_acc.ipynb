# %%
classes=[]
with open("class_based_acc_train.txt","r") as f:
    for line in f:
        classes.append(line.split("/")[0])
unique_classes=set(classes)

# %%
len(unique_classes)
# Out:
# 64

# %%
all_lines=[]
with open("class_based_acc_train.txt","r") as f:
    for line in f:
        all_lines.append(line)

# %%
class_based_lines={}
for cl in unique_classes:
    class_lines=[]
    for line in all_lines:
        if line.split("/")[0]==cl:
            class_lines.append(line)
    class_based_lines[cl]=class_lines

# %%
class_scores={}
for cl in unique_classes:
    total=0
    tp=0
    for line in class_based_lines[cl]:
        splitted=line.split("/")
        tp+=int(splitted[1])
        total+=int(splitted[2])
    class_scores[cl]=[tp,total,float(tp)/float(total)]

# %%
class_scores
# Out:
# {'n04612504': [97376, 101385, 0.960457661389752],
#  'n07584110': [97755, 102765, 0.9512479929937235],
#  'n13054560': [93170, 102960, 0.9049145299145299],
#  'n04604644': [91302, 102450, 0.8911859443631039],
#  'n02105505': [97424, 105135, 0.9266562039282826],
#  'n01910747': [95224, 102570, 0.9283806181144584],
#  'n09246464': [96426, 103800, 0.9289595375722544],
#  'n02108089': [93903, 103560, 0.9067497103128621],
#  'n07747607': [96977, 102750, 0.9438150851581508],
#  'n03476684': [88555, 103470, 0.8558519377597371],
#  'n02091831': [92483, 101520, 0.9109830575256107],
#  'n02111277': [95423, 103155, 0.9250448354418108],
#  'n03220513': [91913, 102870, 0.8934869252454555],
#  'n02113712': [96301, 105360, 0.9140186028853455],
#  'n01558993': [93702, 101865, 0.9198645265792962],
#  'n02457408': [93462, 103620, 0.9019687319050377],
#  'n04443257': [93546, 102870, 0.9093613298337708],
#  'n03676483': [88908, 100965, 0.8805823800326846],
#  'n02108915': [94732, 104640, 0.9053134556574923],
#  'n02606052': [97743, 102270, 0.9557348195951892],
#  'n03888605': [88171, 103785, 0.8495543672014261],
#  'n04275548': [93043, 104025, 0.8944292237442922],
#  'n02966193': [94123, 103935, 0.9055948429306778],
#  'n01704323': [92233, 103875, 0.8879229843561973],
#  'n02747177': [86290, 101640, 0.8489767807949626],
#  'n01843383': [96756, 105360, 0.9183371298405467],
#  'n03527444': [87020, 101700, 0.855653883972468],
#  'n02089867': [95925, 104010, 0.9222670897029132],
#  'n01770081': [94770, 102570, 0.9239543726235742],
#  'n04596742': [87802, 101910, 0.8615641252085173],
#  'n04509417': [90446, 103605, 0.8729887553689494],
#  'n03337140': [94019, 102405, 0.9181094673111665],
#  'n04243546': [97093, 103485, 0.9382325940957627],
#  'n03347037': [93456, 105165, 0.888660676080445],
#  'n03838899': [86242, 101505, 0.849633023003793],
#  'n02101006': [96438, 104175, 0.9257307415406767],
#  'n04258138': [92248, 104445, 0.8832208339317345],
#  'n06794110': [92957, 103680, 0.8965760030864197],
#  'n03017168': [83542, 102285, 0.81675710025908],
#  'n03047690': [87418, 103560, 0.8441290073387409],
#  'n01749939': [95385, 102525, 0.9303584491587418],
#  'n04435653': [91158, 102975, 0.8852439912600145],
#  'n02165456': [97522, 103500, 0.9422415458937198],
#  'n03062245': [92385, 105495, 0.8757287075216835],
#  'n02687172': [97026, 102810, 0.9437408812372338],
#  'n02074367': [97338, 101820, 0.9559811431938715],
#  'n04296562': [89524, 101520, 0.8818360914105595],
#  'n04389033': [94533, 103725, 0.9113810556760665],
#  'n13133613': [90574, 104235, 0.8689403751139253],
#  'n04515003': [91743, 100695, 0.9110978698048563],
#  'n02823428': [87736, 102375, 0.857006105006105],
#  'n03854065': [95573, 104280, 0.9165036440352896],
#  'n04251144': [90139, 101745, 0.8859305125558996],
#  'n03908618': [88966, 102720, 0.8661020249221184],
#  'n01532829': [92342, 102285, 0.9027912206090825],
#  'n02120079': [96222, 103545, 0.9292771258872954],
#  'n03400231': [90826, 104895, 0.8658753992087326],
#  'n07697537': [95019, 103605, 0.917127551759085],
#  'n03998194': [94372, 104670, 0.9016145982612018],
#  'n02108551': [96088, 101730, 0.9445394672171434],
#  'n04067472': [85004, 103170, 0.8239216826596879],
#  'n03207743': [94326, 102570, 0.9196256215267622],
#  'n02795169': [84498, 102030, 0.8281681858276977],
#  'n03924679': [95767, 103530, 0.9250169033130493]}
